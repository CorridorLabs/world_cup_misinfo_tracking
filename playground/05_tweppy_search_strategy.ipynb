# %% [markdown]
# # 05_tweepy_search_strategy
#
# Assuming we might be in a situation where we don't want to stream tweets, but instead want to search (within a timeframe of the past 7 days), we have to follow a different pathway in the tweepy module -- the `Client` rather than `StreamingClient`. Let us see here if this means we can achieve similar results as through streaming, but after the fact.
#
# NL, 05/12/22

# %% [markdown]
# ## IMPORTS

# %%
import os
from dotenv import load_dotenv
import json
import re
import datetime
from dateutil import parser as date_parser
import tweepy

# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# (just recycling existing functions from `01_`)

# %%
def check_path_exists(filepath:str):
    '''
    checks if a supplied filepath 
    (dir + filename) exists. if the full path
    with file is not a file, checks for 
    just the dir path and creates file if exists, 
    raises error if not
    
    args:
        - filepath: str, full file path
    '''
    if filepath is None:
        raise TypeError(f'specified path is None.')

    if not isinstance(filepath, str):
        raise TypeError(f'filepath object must be\
            str. Please re-specify.')

    if os.path.isdir(filepath):
        raise ValueError(f'Need to provide a full path to a file,\
            not a dir.')

    if not os.path.isfile(filepath):
        # split and check if everything before the last 
        # `/` is a dir
        splits = filepath.split('/')
        concat = '/'.join(splits[:-1])+'/'
        if not os.path.isdir(concat):
            raise NotADirectoryError(f'Directory path \
                {concat} does not exist. Please re-specify\
                    `out_path`.')
        else:
            print(f'{concat}, the dir in for\
                specified filepath is a directory, but\
                    file {splits[-1:]} does not exist.\
                        Thats fine for us.')
            return filepath
    
    else: 
        return filepath

# %%
def extract_count_domains_entities(context_field:list):
    '''
    entracts the counts of domains and entities in 
    a given tweet.

    returns:
        - domains, dict
        - entities, dict
    '''
    domains = {}
    entities = {}

    for context in context_field:
        # domain
        if context['domain']['name'] not in domains.keys():
            domains[context['domain']['name']] = 1
        else:
            domains[context['domain']['name']] += 1

        # entity
        if context['entity']['name'] not in entities.keys():
            entities[context['entity']['name']] = 1
        else:
            entities[context['entity']['name']] += 1

    return domains, entities

# %%
def total_domain_entity_counts(domains_tweet:dict,
                               domains_session:dict,
                               entities_tweet:dict,
                               entities_session:dict):
    ''' 
    accumulates counts for domains and entities
    for the entire streaming session.  
    '''
    for domain in domains_tweet.keys():
        if domain not in domains_session.keys():
            domains_session[domain] = 1
        else:
            domains_session[domain] += 1

    for entity in entities_tweet.keys():
        if entity not in entities_session.keys():
            entities_session[entity] = 1
        else:
            entities_session[entity] += 1

    return domains_session, entities_session

# %%
def extract_urls(tweet_text:str) -> list:
    '''
    extracts urls from tweet text
    returns all urls in tweet text in list
    '''
    urls = re.findall("http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", tweet_text)

    return urls

# %% [markdown]
# ## INIT

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ## PATHS & CONSTANTS

# %%
SEARCH_TERMS = '/home/nikloynes/projects/world_cup_misinfo_tracking/data_collection/twitter_search_terms.txt'

# %%
# build query string from search terms
with open(SEARCH_TERMS, 'r') as infile:
    search_terms = "".join(['('+line.rstrip()+')'+' OR ' for line in infile][:5])

# %%
# drop the final 'or'
search_terms = search_terms[:-4]

# %%
bearer_token = os.getenv('TWITTER_BEARER_TOKEN')

# %%
expansions = ['author_id', 'referenced_tweets.id']
tweet_fields = ['created_at', 'public_metrics', 'source', 'context_annotations']
media_fields = ['media_key', 'type', 'url', 'duration_ms']
user_fields = ['id', 'name', 'username', 'created_at', 'description', 'location', 'public_metrics', 'protected']

# %%
# time stamps
# we want to generate a list of dicts with 8 entries. for each entry we will have these keys: filename, start_time, end_time
earliest = date_parser.parse('2022-12-04 16:00:01')
delta = datetime.timedelta(minutes=59)
time_chunks = []

for i in range(8):
    tmp = {
        'start_time' : earliest,
        'end_time' : earliest+delta,
        'filename' : 'tweets_'+earliest.strftime('%Y_%m_%d-%H_%M_%S')+'.json'
    }

    time_chunks.append(tmp)
    earliest = earliest + datetime.timedelta(hours=1)

# %% [markdown]
# ## THE THING!

# %% [markdown]
# we will now test this and see what we the object it returns looks like. we want to create an outfile that is exactly the same as with the streaming approach

# %%
client = tweepy.Client(bearer_token=bearer_token, wait_on_rate_limit=True)

# %%
tweets = client.search_recent_tweets(
    query=search_terms,
    start_time=time_chunks[0]['start_time'],
    end_time=time_chunks[0]['end_time'],
    expansions=expansions, 
    tweet_fields=tweet_fields,
    media_fields=media_fields,
    user_fields=user_fields,
    max_results=100
)

# %%
core_fields = ['author_id', 'created_at', 'id', 'public_metrics', 'referenced_tweets', 'source', 'text'] 
user_fields = ['created_at', 'description', 'id', 'location', 'name', 'public_metrics', 'username']
out_dir = '../data/test/'

# %%
for i in range(len(tweets[0])):
    tmp_dict = tweets[0][i].data
    tmp_user = tweets[1]['users'][i].data

    out = {}
    for field in core_fields:
        if field in tmp_dict:
            out[field] = tmp_dict[field]

    urls = extract_urls(tmp_dict['text'])
    if len(urls)>0:
        out['urls'] = urls

    # extract domain and entity counts
    if 'context_annotations' in tmp_dict.keys():
        domains, entities = extract_count_domains_entities(tmp_dict['context_annotations'])
        out['domains'] = domains
        out['entities'] = entities

    # add user stuff
    user = {}
    for field in user_fields:
        if field in tmp_user:
            user[field] = tmp_user[field]

    out['user'] = user

    with open(out_dir+time_chunks[0]['filename'], 'a') as o:
        o.write(json.dumps(out)+'\n')

# %% [markdown]
# OK - that works. we were able to retrieve 10 (100) tweets using this approach, and then write them out to json in the standard format.
# Now, let's expand this to include pagination, and run it.

# %%
it_counter = 0
n_tweets = 0

for tweets in tweepy.Paginator(client.search_recent_tweets, 
                               query=search_terms,
                               start_time=time_chunks[0]['start_time'],
                            #    end_time=time_chunks[0]['end_time'],
                               end_time=tmp_start_time,
                               expansions=expansions, 
                               tweet_fields=tweet_fields,
                               media_fields=media_fields,
                               user_fields=user_fields,
                               max_results=100,
                               limit=970):
                            #    limit=1000):
    it_counter += 1
    print(f'on page {it_counter} out of 1000. n tweets collected so far: {n_tweets}')
    
    # the 'tweets' object is the same as what we had above. 
    # so we need to iterate over it again.
    for i in range(len(tweets[0])):
        tmp_dict = tweets[0][i].data
        author_id = tmp_dict['author_id']
        tmp_user = {}
        
        try:
            tmp_user = tweets[1]['users'][i].data
            if tmp_user['id']!=author_id:
                # we now need to find the correct user object in there
                for user_obj in tweets[1]['users']:
                    if user_obj.data['id']==author_id:
                        tmp_user = user_obj.data
        except IndexError:
            for user_obj in tweets[1]['users']:
                if user_obj.data['id']==author_id:
                    tmp_user = user_obj.data
        
        if 'id' in tmp_user.keys():
            if tmp_user['id']!=author_id:
                tmp_user = {'not available'}

        out = {}
        for field in core_fields:
            if field in tmp_dict:
                out[field] = tmp_dict[field]

        urls = extract_urls(tmp_dict['text'])
        if len(urls)>0:
            out['urls'] = urls

        # extract domain and entity counts
        if 'context_annotations' in tmp_dict.keys():
            domains, entities = extract_count_domains_entities(tmp_dict['context_annotations'])
            out['domains'] = domains
            out['entities'] = entities

        # add user stuff
        user = {}
        if tmp_user!={'not available'}:
            for field in user_fields:
                if field in tmp_user:
                    user[field] = tmp_user[field]

            out['user'] = user
        else:
            out['user'] = tmp_user

        with open(out_dir+time_chunks[0]['filename'], 'a') as o:
            o.write(json.dumps(out)+'\n')

        n_tweets += 1
# Out:
# on page 1 out of 1000. n tweets collected so far: 0
# on page 2 out of 1000. n tweets collected so far: 98
# on page 3 out of 1000. n tweets collected so far: 197
# on page 4 out of 1000. n tweets collected so far: 297
# on page 5 out of 1000. n tweets collected so far: 397
# on page 6 out of 1000. n tweets collected so far: 497
# on page 7 out of 1000. n tweets collected so far: 597
# on page 8 out of 1000. n tweets collected so far: 697
# on page 9 out of 1000. n tweets collected so far: 797
# on page 10 out of 1000. n tweets collected so far: 896
# on page 11 out of 1000. n tweets collected so far: 995
# on page 12 out of 1000. n tweets collected so far: 1094
# on page 13 out of 1000. n tweets collected so far: 1194
# on page 14 out of 1000. n tweets collected so far: 1293
# on page 15 out of 1000. n tweets collected so far: 1393
# on page 16 out of 1000. n tweets collected so far: 1493
# on page 17 out of 1000. n tweets collected so far: 1593
# on page 18 out of 1000. n tweets collected so far: 1693
# on page 19 out of 1000. n tweets collected so far: 1793
# on page 20 out of 1000. n tweets collected so far: 1893
# on page 21 out of 1000. n tweets collected so far: 1992
# on page 22 out of 1000. n tweets collected so far: 2092
# on page 23 out of 1000. n tweets collected so far: 2191
# on page 24 out of 1000. n tweets collected so far: 2291
# on page 25 out of 1000. n tweets collected so far: 2391
# on page 26 out of 1000. n tweets collected so far: 2491
# on page 27 out of 1000. n tweets collected so far: 2591
# on page 28 out of 1000. n tweets collected so far: 2691
# on page 29 out of 1000. n tweets collected so far: 2791
# on page 30 out of 1000. n tweets collected so far: 2890
# on page 31 out of 1000. n tweets collected so far: 2990
# on page 32 out of 1000. n tweets collected so far: 3090
# on page 33 out of 1000. n tweets collected so far: 3189
# on page 34 out of 1000. n tweets collected so far: 3288
# on page 35 out of 1000. n tweets collected so far: 3388
# on page 36 out of 1000. n tweets collected so far: 3488
# on page 37 out of 1000. n tweets collected so far: 3588
# on page 38 out of 1000. n tweets collected so far: 3688
# on page 39 out of 1000. n tweets collected so far: 3788
# on page 40 out of 1000. n tweets collected so far: 3888
# on page 41 out of 1000. n tweets collected so far: 3988
# on page 42 out of 1000. n tweets collected so far: 4088
# on page 43 out of 1000. n tweets collected so far: 4188
# on page 44 out of 1000. n tweets collected so far: 4287
# on page 45 out of 1000. n tweets collected so far: 4386
# on page 46 out of 1000. n tweets collected so far: 4486
# on page 47 out of 1000. n tweets collected so far: 4586
# on page 48 out of 1000. n tweets collected so far: 4686
# on page 49 out of 1000. n tweets collected so far: 4786
# on page 50 out of 1000. n tweets collected so far: 4886
# on page 51 out of 1000. n tweets collected so far: 4986
# on page 52 out of 1000. n tweets collected so far: 5085
# on page 53 out of 1000. n tweets collected so far: 5185
# on page 54 out of 1000. n tweets collected so far: 5285
# on page 55 out of 1000. n tweets collected so far: 5385
# on page 56 out of 1000. n tweets collected so far: 5484
# on page 57 out of 1000. n tweets collected so far: 5584
# on page 58 out of 1000. n tweets collected so far: 5684
# on page 59 out of 1000. n tweets collected so far: 5783
# on page 60 out of 1000. n tweets collected so far: 5883
# on page 61 out of 1000. n tweets collected so far: 5982
# on page 62 out of 1000. n tweets collected so far: 6081
# on page 63 out of 1000. n tweets collected so far: 6181
# on page 64 out of 1000. n tweets collected so far: 6280
# on page 65 out of 1000. n tweets collected so far: 6380
# on page 66 out of 1000. n tweets collected so far: 6480
# on page 67 out of 1000. n tweets collected so far: 6580
# on page 68 out of 1000. n tweets collected so far: 6679
# on page 69 out of 1000. n tweets collected so far: 6777
# on page 70 out of 1000. n tweets collected so far: 6876
# on page 71 out of 1000. n tweets collected so far: 6976
# on page 72 out of 1000. n tweets collected so far: 7075
# on page 73 out of 1000. n tweets collected so far: 7175
# on page 74 out of 1000. n tweets collected so far: 7275
# on page 75 out of 1000. n tweets collected so far: 7375
# on page 76 out of 1000. n tweets collected so far: 7475
# on page 77 out of 1000. n tweets collected so far: 7575
# on page 78 out of 1000. n tweets collected so far: 7675
# on page 79 out of 1000. n tweets collected so far: 7775
# on page 80 out of 1000. n tweets collected so far: 7875
# on page 81 out of 1000. n tweets collected so far: 7975
# on page 82 out of 1000. n tweets collected so far: 8074
# on page 83 out of 1000. n tweets collected so far: 8174
# on page 84 out of 1000. n tweets collected so far: 8274
# on page 85 out of 1000. n tweets collected so far: 8374
# on page 86 out of 1000. n tweets collected so far: 8474
# on page 87 out of 1000. n tweets collected so far: 8574
# on page 88 out of 1000. n tweets collected so far: 8674
# on page 89 out of 1000. n tweets collected so far: 8773
# on page 90 out of 1000. n tweets collected so far: 8873
# on page 91 out of 1000. n tweets collected so far: 8973
# on page 92 out of 1000. n tweets collected so far: 9073
# on page 93 out of 1000. n tweets collected so far: 9173
# on page 94 out of 1000. n tweets collected so far: 9273
# on page 95 out of 1000. n tweets collected so far: 9372
# on page 96 out of 1000. n tweets collected so far: 9472
# on page 97 out of 1000. n tweets collected so far: 9572
# on page 98 out of 1000. n tweets collected so far: 9672
# on page 99 out of 1000. n tweets collected so far: 9772
# on page 100 out of 1000. n tweets collected so far: 9872
# on page 101 out of 1000. n tweets collected so far: 9972
# on page 102 out of 1000. n tweets collected so far: 10072
# on page 103 out of 1000. n tweets collected so far: 10172
# on page 104 out of 1000. n tweets collected so far: 10272
# on page 105 out of 1000. n tweets collected so far: 10371
# on page 106 out of 1000. n tweets collected so far: 10471
# on page 107 out of 1000. n tweets collected so far: 10571
# on page 108 out of 1000. n tweets collected so far: 10671
# on page 109 out of 1000. n tweets collected so far: 10771
# on page 110 out of 1000. n tweets collected so far: 10871
# on page 111 out of 1000. n tweets collected so far: 10971
# on page 112 out of 1000. n tweets collected so far: 11070
# on page 113 out of 1000. n tweets collected so far: 11170
# on page 114 out of 1000. n tweets collected so far: 11270
# on page 115 out of 1000. n tweets collected so far: 11370
# on page 116 out of 1000. n tweets collected so far: 11469
# on page 117 out of 1000. n tweets collected so far: 11569
# on page 118 out of 1000. n tweets collected so far: 11669
# on page 119 out of 1000. n tweets collected so far: 11769
# on page 120 out of 1000. n tweets collected so far: 11869
# on page 121 out of 1000. n tweets collected so far: 11969
# on page 122 out of 1000. n tweets collected so far: 12068
# on page 123 out of 1000. n tweets collected so far: 12168
# on page 124 out of 1000. n tweets collected so far: 12268
# on page 125 out of 1000. n tweets collected so far: 12367
# on page 126 out of 1000. n tweets collected so far: 12467
# on page 127 out of 1000. n tweets collected so far: 12567
# on page 128 out of 1000. n tweets collected so far: 12667
# on page 129 out of 1000. n tweets collected so far: 12766
# on page 130 out of 1000. n tweets collected so far: 12866
# on page 131 out of 1000. n tweets collected so far: 12966
# on page 132 out of 1000. n tweets collected so far: 13066
# on page 133 out of 1000. n tweets collected so far: 13166
# on page 134 out of 1000. n tweets collected so far: 13266
# on page 135 out of 1000. n tweets collected so far: 13366
# on page 136 out of 1000. n tweets collected so far: 13466
# on page 137 out of 1000. n tweets collected so far: 13566
# on page 138 out of 1000. n tweets collected so far: 13666
# on page 139 out of 1000. n tweets collected so far: 13766
# on page 140 out of 1000. n tweets collected so far: 13866
# on page 141 out of 1000. n tweets collected so far: 13965
# on page 142 out of 1000. n tweets collected so far: 14065
# on page 143 out of 1000. n tweets collected so far: 14165
# on page 144 out of 1000. n tweets collected so far: 14265
# on page 145 out of 1000. n tweets collected so far: 14364
# on page 146 out of 1000. n tweets collected so far: 14464
# on page 147 out of 1000. n tweets collected so far: 14563
# on page 148 out of 1000. n tweets collected so far: 14663
# on page 149 out of 1000. n tweets collected so far: 14762
# on page 150 out of 1000. n tweets collected so far: 14861
# on page 151 out of 1000. n tweets collected so far: 14960
# on page 152 out of 1000. n tweets collected so far: 15060
# on page 153 out of 1000. n tweets collected so far: 15160
# on page 154 out of 1000. n tweets collected so far: 15259
# on page 155 out of 1000. n tweets collected so far: 15359
# on page 156 out of 1000. n tweets collected so far: 15459
# on page 157 out of 1000. n tweets collected so far: 15559
# on page 158 out of 1000. n tweets collected so far: 15657
# on page 159 out of 1000. n tweets collected so far: 15757
# on page 160 out of 1000. n tweets collected so far: 15857
# on page 161 out of 1000. n tweets collected so far: 15957
# on page 162 out of 1000. n tweets collected so far: 16057
# on page 163 out of 1000. n tweets collected so far: 16157
# on page 164 out of 1000. n tweets collected so far: 16257
# on page 165 out of 1000. n tweets collected so far: 16356
# on page 166 out of 1000. n tweets collected so far: 16456
# on page 167 out of 1000. n tweets collected so far: 16555
# on page 168 out of 1000. n tweets collected so far: 16654
# on page 169 out of 1000. n tweets collected so far: 16754
# on page 170 out of 1000. n tweets collected so far: 16854
# on page 171 out of 1000. n tweets collected so far: 16954
# on page 172 out of 1000. n tweets collected so far: 17054
# on page 173 out of 1000. n tweets collected so far: 17154
# on page 174 out of 1000. n tweets collected so far: 17254
# on page 175 out of 1000. n tweets collected so far: 17354
# on page 176 out of 1000. n tweets collected so far: 17454
# on page 177 out of 1000. n tweets collected so far: 17554
# on page 178 out of 1000. n tweets collected so far: 17654
# on page 179 out of 1000. n tweets collected so far: 17754
# on page 180 out of 1000. n tweets collected so far: 17854
# on page 181 out of 1000. n tweets collected so far: 17954
# on page 182 out of 1000. n tweets collected so far: 18054
# on page 183 out of 1000. n tweets collected so far: 18154
# on page 184 out of 1000. n tweets collected so far: 18253
# on page 185 out of 1000. n tweets collected so far: 18353
# on page 186 out of 1000. n tweets collected so far: 18453
# on page 187 out of 1000. n tweets collected so far: 18553
# on page 188 out of 1000. n tweets collected so far: 18653
# on page 189 out of 1000. n tweets collected so far: 18751
# on page 190 out of 1000. n tweets collected so far: 18851
# on page 191 out of 1000. n tweets collected so far: 18951
# on page 192 out of 1000. n tweets collected so far: 19051
# on page 193 out of 1000. n tweets collected so far: 19150
# on page 194 out of 1000. n tweets collected so far: 19249
# on page 195 out of 1000. n tweets collected so far: 19349
# on page 196 out of 1000. n tweets collected so far: 19449
# on page 197 out of 1000. n tweets collected so far: 19549
# on page 198 out of 1000. n tweets collected so far: 19648
# on page 199 out of 1000. n tweets collected so far: 19748
# on page 200 out of 1000. n tweets collected so far: 19848
# on page 201 out of 1000. n tweets collected so far: 19948
# on page 202 out of 1000. n tweets collected so far: 20048
# on page 203 out of 1000. n tweets collected so far: 20148
# on page 204 out of 1000. n tweets collected so far: 20248
# on page 205 out of 1000. n tweets collected so far: 20348
# on page 206 out of 1000. n tweets collected so far: 20448
# on page 207 out of 1000. n tweets collected so far: 20548
# on page 208 out of 1000. n tweets collected so far: 20647
# on page 209 out of 1000. n tweets collected so far: 20747
# on page 210 out of 1000. n tweets collected so far: 20847
# on page 211 out of 1000. n tweets collected so far: 20947
# on page 212 out of 1000. n tweets collected so far: 21046
# on page 213 out of 1000. n tweets collected so far: 21146
# on page 214 out of 1000. n tweets collected so far: 21246
# on page 215 out of 1000. n tweets collected so far: 21346
# on page 216 out of 1000. n tweets collected so far: 21446
# on page 217 out of 1000. n tweets collected so far: 21546
# on page 218 out of 1000. n tweets collected so far: 21646
# on page 219 out of 1000. n tweets collected so far: 21746
# on page 220 out of 1000. n tweets collected so far: 21846
# on page 221 out of 1000. n tweets collected so far: 21946
# on page 222 out of 1000. n tweets collected so far: 22046
# on page 223 out of 1000. n tweets collected so far: 22145
# on page 224 out of 1000. n tweets collected so far: 22245
# on page 225 out of 1000. n tweets collected so far: 22343
# on page 226 out of 1000. n tweets collected so far: 22443
# on page 227 out of 1000. n tweets collected so far: 22543
# on page 228 out of 1000. n tweets collected so far: 22643
# on page 229 out of 1000. n tweets collected so far: 22743
# on page 230 out of 1000. n tweets collected so far: 22843
# on page 231 out of 1000. n tweets collected so far: 22942
# on page 232 out of 1000. n tweets collected so far: 23042
# on page 233 out of 1000. n tweets collected so far: 23141
# on page 234 out of 1000. n tweets collected so far: 23239
# on page 235 out of 1000. n tweets collected so far: 23339
# on page 236 out of 1000. n tweets collected so far: 23438
# on page 237 out of 1000. n tweets collected so far: 23538
# on page 238 out of 1000. n tweets collected so far: 23637
# on page 239 out of 1000. n tweets collected so far: 23736
# on page 240 out of 1000. n tweets collected so far: 23836
# on page 241 out of 1000. n tweets collected so far: 23936
# on page 242 out of 1000. n tweets collected so far: 24036
# on page 243 out of 1000. n tweets collected so far: 24135
# on page 244 out of 1000. n tweets collected so far: 24234
# on page 245 out of 1000. n tweets collected so far: 24333
# on page 246 out of 1000. n tweets collected so far: 24432
# on page 247 out of 1000. n tweets collected so far: 24532
# on page 248 out of 1000. n tweets collected so far: 24631
# on page 249 out of 1000. n tweets collected so far: 24731
# on page 250 out of 1000. n tweets collected so far: 24831
# on page 251 out of 1000. n tweets collected so far: 24931
# on page 252 out of 1000. n tweets collected so far: 25031
# on page 253 out of 1000. n tweets collected so far: 25131
# on page 254 out of 1000. n tweets collected so far: 25231
# on page 255 out of 1000. n tweets collected so far: 25331
# on page 256 out of 1000. n tweets collected so far: 25431
# on page 257 out of 1000. n tweets collected so far: 25531
# on page 258 out of 1000. n tweets collected so far: 25631
# on page 259 out of 1000. n tweets collected so far: 25731
# on page 260 out of 1000. n tweets collected so far: 25831
# on page 261 out of 1000. n tweets collected so far: 25930
# on page 262 out of 1000. n tweets collected so far: 26030
# on page 263 out of 1000. n tweets collected so far: 26130
# on page 264 out of 1000. n tweets collected so far: 26230
# on page 265 out of 1000. n tweets collected so far: 26330
# on page 266 out of 1000. n tweets collected so far: 26430
# on page 267 out of 1000. n tweets collected so far: 26530
# on page 268 out of 1000. n tweets collected so far: 26630
# on page 269 out of 1000. n tweets collected so far: 26730
# on page 270 out of 1000. n tweets collected so far: 26830
# on page 271 out of 1000. n tweets collected so far: 26930
# on page 272 out of 1000. n tweets collected so far: 27029
# on page 273 out of 1000. n tweets collected so far: 27129
# on page 274 out of 1000. n tweets collected so far: 27229
# on page 275 out of 1000. n tweets collected so far: 27329
# on page 276 out of 1000. n tweets collected so far: 27429
# on page 277 out of 1000. n tweets collected so far: 27528
# on page 278 out of 1000. n tweets collected so far: 27628
# on page 279 out of 1000. n tweets collected so far: 27728
# on page 280 out of 1000. n tweets collected so far: 27828
# on page 281 out of 1000. n tweets collected so far: 27927
# on page 282 out of 1000. n tweets collected so far: 28026
# on page 283 out of 1000. n tweets collected so far: 28126
# on page 284 out of 1000. n tweets collected so far: 28226
# on page 285 out of 1000. n tweets collected so far: 28326
# on page 286 out of 1000. n tweets collected so far: 28426
# on page 287 out of 1000. n tweets collected so far: 28525
# on page 288 out of 1000. n tweets collected so far: 28625
# on page 289 out of 1000. n tweets collected so far: 28725
# on page 290 out of 1000. n tweets collected so far: 28824
# on page 291 out of 1000. n tweets collected so far: 28924
# on page 292 out of 1000. n tweets collected so far: 29024
# on page 293 out of 1000. n tweets collected so far: 29124
# on page 294 out of 1000. n tweets collected so far: 29224
# on page 295 out of 1000. n tweets collected so far: 29324
# on page 296 out of 1000. n tweets collected so far: 29422
# on page 297 out of 1000. n tweets collected so far: 29522
# on page 298 out of 1000. n tweets collected so far: 29622
# on page 299 out of 1000. n tweets collected so far: 29722
# on page 300 out of 1000. n tweets collected so far: 29822
# on page 301 out of 1000. n tweets collected so far: 29922
# on page 302 out of 1000. n tweets collected so far: 30022
# on page 303 out of 1000. n tweets collected so far: 30122
# on page 304 out of 1000. n tweets collected so far: 30222
# on page 305 out of 1000. n tweets collected so far: 30322
# on page 306 out of 1000. n tweets collected so far: 30422
# on page 307 out of 1000. n tweets collected so far: 30522
# on page 308 out of 1000. n tweets collected so far: 30622
# on page 309 out of 1000. n tweets collected so far: 30722
# on page 310 out of 1000. n tweets collected so far: 30821
# on page 311 out of 1000. n tweets collected so far: 30921
# on page 312 out of 1000. n tweets collected so far: 31021
# on page 313 out of 1000. n tweets collected so far: 31121
# on page 314 out of 1000. n tweets collected so far: 31221
# on page 315 out of 1000. n tweets collected so far: 31321
# on page 316 out of 1000. n tweets collected so far: 31421
# on page 317 out of 1000. n tweets collected so far: 31520
# on page 318 out of 1000. n tweets collected so far: 31620
# on page 319 out of 1000. n tweets collected so far: 31720
# on page 320 out of 1000. n tweets collected so far: 31820
# on page 321 out of 1000. n tweets collected so far: 31920
# on page 322 out of 1000. n tweets collected so far: 32020
# on page 323 out of 1000. n tweets collected so far: 32119
# on page 324 out of 1000. n tweets collected so far: 32218
# on page 325 out of 1000. n tweets collected so far: 32317
# on page 326 out of 1000. n tweets collected so far: 32417
# on page 327 out of 1000. n tweets collected so far: 32517
# on page 328 out of 1000. n tweets collected so far: 32617
# on page 329 out of 1000. n tweets collected so far: 32716
# on page 330 out of 1000. n tweets collected so far: 32816
# on page 331 out of 1000. n tweets collected so far: 32915
# on page 332 out of 1000. n tweets collected so far: 33015
# on page 333 out of 1000. n tweets collected so far: 33115
# on page 334 out of 1000. n tweets collected so far: 33215
# on page 335 out of 1000. n tweets collected so far: 33315
# on page 336 out of 1000. n tweets collected so far: 33415
# on page 337 out of 1000. n tweets collected so far: 33514
# on page 338 out of 1000. n tweets collected so far: 33614
# on page 339 out of 1000. n tweets collected so far: 33713
# on page 340 out of 1000. n tweets collected so far: 33813
# on page 341 out of 1000. n tweets collected so far: 33912
# on page 342 out of 1000. n tweets collected so far: 34011
# on page 343 out of 1000. n tweets collected so far: 34111
# on page 344 out of 1000. n tweets collected so far: 34211
# on page 345 out of 1000. n tweets collected so far: 34311
# on page 346 out of 1000. n tweets collected so far: 34410
# on page 347 out of 1000. n tweets collected so far: 34510
# on page 348 out of 1000. n tweets collected so far: 34610
# on page 349 out of 1000. n tweets collected so far: 34709
# on page 350 out of 1000. n tweets collected so far: 34809
# on page 351 out of 1000. n tweets collected so far: 34909
# on page 352 out of 1000. n tweets collected so far: 35008
# on page 353 out of 1000. n tweets collected so far: 35108
# on page 354 out of 1000. n tweets collected so far: 35208
# on page 355 out of 1000. n tweets collected so far: 35307
# on page 356 out of 1000. n tweets collected so far: 35406
# on page 357 out of 1000. n tweets collected so far: 35505
# on page 358 out of 1000. n tweets collected so far: 35605
# on page 359 out of 1000. n tweets collected so far: 35704
# on page 360 out of 1000. n tweets collected so far: 35804
# on page 361 out of 1000. n tweets collected so far: 35904
# on page 362 out of 1000. n tweets collected so far: 36004
# on page 363 out of 1000. n tweets collected so far: 36103
# on page 364 out of 1000. n tweets collected so far: 36202
# on page 365 out of 1000. n tweets collected so far: 36302
# on page 366 out of 1000. n tweets collected so far: 36401
# on page 367 out of 1000. n tweets collected so far: 36500
# on page 368 out of 1000. n tweets collected so far: 36599
# on page 369 out of 1000. n tweets collected so far: 36699
# on page 370 out of 1000. n tweets collected so far: 36799
# on page 371 out of 1000. n tweets collected so far: 36899
# on page 372 out of 1000. n tweets collected so far: 36999
# on page 373 out of 1000. n tweets collected so far: 37099
# on page 374 out of 1000. n tweets collected so far: 37199
# on page 375 out of 1000. n tweets collected so far: 37299
# on page 376 out of 1000. n tweets collected so far: 37398
# on page 377 out of 1000. n tweets collected so far: 37498
# on page 378 out of 1000. n tweets collected so far: 37597
# on page 379 out of 1000. n tweets collected so far: 37697
# on page 380 out of 1000. n tweets collected so far: 37797
# on page 381 out of 1000. n tweets collected so far: 37897
# on page 382 out of 1000. n tweets collected so far: 37997
# on page 383 out of 1000. n tweets collected so far: 38097
# on page 384 out of 1000. n tweets collected so far: 38197
# on page 385 out of 1000. n tweets collected so far: 38296
# on page 386 out of 1000. n tweets collected so far: 38396
# on page 387 out of 1000. n tweets collected so far: 38495
# on page 388 out of 1000. n tweets collected so far: 38594
# on page 389 out of 1000. n tweets collected so far: 38694
# on page 390 out of 1000. n tweets collected so far: 38794
# on page 391 out of 1000. n tweets collected so far: 38894
# on page 392 out of 1000. n tweets collected so far: 38994
# on page 393 out of 1000. n tweets collected so far: 39093
# on page 394 out of 1000. n tweets collected so far: 39193
# on page 395 out of 1000. n tweets collected so far: 39293
# on page 396 out of 1000. n tweets collected so far: 39392
# on page 397 out of 1000. n tweets collected so far: 39491
# on page 398 out of 1000. n tweets collected so far: 39591
# on page 399 out of 1000. n tweets collected so far: 39691
# on page 400 out of 1000. n tweets collected so far: 39791
# on page 401 out of 1000. n tweets collected so far: 39891
# on page 402 out of 1000. n tweets collected so far: 39991
# on page 403 out of 1000. n tweets collected so far: 40091
# on page 404 out of 1000. n tweets collected so far: 40191
# on page 405 out of 1000. n tweets collected so far: 40291
# on page 406 out of 1000. n tweets collected so far: 40391
# on page 407 out of 1000. n tweets collected so far: 40491
# on page 408 out of 1000. n tweets collected so far: 40591
# on page 409 out of 1000. n tweets collected so far: 40691
# on page 410 out of 1000. n tweets collected so far: 40791
# on page 411 out of 1000. n tweets collected so far: 40891
# on page 412 out of 1000. n tweets collected so far: 40991
# on page 413 out of 1000. n tweets collected so far: 41090
# on page 414 out of 1000. n tweets collected so far: 41190
# on page 415 out of 1000. n tweets collected so far: 41290
# on page 416 out of 1000. n tweets collected so far: 41390
# on page 417 out of 1000. n tweets collected so far: 41489
# on page 418 out of 1000. n tweets collected so far: 41589
# on page 419 out of 1000. n tweets collected so far: 41688
# on page 420 out of 1000. n tweets collected so far: 41788
# on page 421 out of 1000. n tweets collected so far: 41888
# on page 422 out of 1000. n tweets collected so far: 41988
# on page 423 out of 1000. n tweets collected so far: 42088
# on page 424 out of 1000. n tweets collected so far: 42187
# on page 425 out of 1000. n tweets collected so far: 42286
# on page 426 out of 1000. n tweets collected so far: 42386
# on page 427 out of 1000. n tweets collected so far: 42486
# on page 428 out of 1000. n tweets collected so far: 42585
# on page 429 out of 1000. n tweets collected so far: 42684
# on page 430 out of 1000. n tweets collected so far: 42784
# on page 431 out of 1000. n tweets collected so far: 42884
# on page 432 out of 1000. n tweets collected so far: 42983
# on page 433 out of 1000. n tweets collected so far: 43083
# on page 434 out of 1000. n tweets collected so far: 43183
# on page 435 out of 1000. n tweets collected so far: 43283
# on page 436 out of 1000. n tweets collected so far: 43383
# on page 437 out of 1000. n tweets collected so far: 43483
# on page 438 out of 1000. n tweets collected so far: 43583
# on page 439 out of 1000. n tweets collected so far: 43683
# on page 440 out of 1000. n tweets collected so far: 43783
# on page 441 out of 1000. n tweets collected so far: 43882
# on page 442 out of 1000. n tweets collected so far: 43982
# on page 443 out of 1000. n tweets collected so far: 44081
# on page 444 out of 1000. n tweets collected so far: 44180
# on page 445 out of 1000. n tweets collected so far: 44280
# on page 446 out of 1000. n tweets collected so far: 44379
# on page 447 out of 1000. n tweets collected so far: 44479
# on page 448 out of 1000. n tweets collected so far: 44579
# on page 449 out of 1000. n tweets collected so far: 44679
# Rate limit exceeded. Sleeping for 251 seconds.
# on page 450 out of 1000. n tweets collected so far: 44778
# on page 451 out of 1000. n tweets collected so far: 44878
# on page 452 out of 1000. n tweets collected so far: 44977
# on page 453 out of 1000. n tweets collected so far: 45077
# on page 454 out of 1000. n tweets collected so far: 45177
# on page 455 out of 1000. n tweets collected so far: 45276
# on page 456 out of 1000. n tweets collected so far: 45376
# on page 457 out of 1000. n tweets collected so far: 45475
# on page 458 out of 1000. n tweets collected so far: 45574
# on page 459 out of 1000. n tweets collected so far: 45674
# on page 460 out of 1000. n tweets collected so far: 45774
# on page 461 out of 1000. n tweets collected so far: 45874
# on page 462 out of 1000. n tweets collected so far: 45974
# on page 463 out of 1000. n tweets collected so far: 46074
# on page 464 out of 1000. n tweets collected so far: 46174
# on page 465 out of 1000. n tweets collected so far: 46273
# on page 466 out of 1000. n tweets collected so far: 46373
# on page 467 out of 1000. n tweets collected so far: 46473
# on page 468 out of 1000. n tweets collected so far: 46573
# on page 469 out of 1000. n tweets collected so far: 46671
# on page 470 out of 1000. n tweets collected so far: 46771
# on page 471 out of 1000. n tweets collected so far: 46871
# on page 472 out of 1000. n tweets collected so far: 46971
# on page 473 out of 1000. n tweets collected so far: 47071
# on page 474 out of 1000. n tweets collected so far: 47171
# on page 475 out of 1000. n tweets collected so far: 47271
# on page 476 out of 1000. n tweets collected so far: 47370
# on page 477 out of 1000. n tweets collected so far: 47468
# on page 478 out of 1000. n tweets collected so far: 47567
# on page 479 out of 1000. n tweets collected so far: 47667
# on page 480 out of 1000. n tweets collected so far: 47767
# on page 481 out of 1000. n tweets collected so far: 47867
# on page 482 out of 1000. n tweets collected so far: 47967
# on page 483 out of 1000. n tweets collected so far: 48067
# on page 484 out of 1000. n tweets collected so far: 48167
# on page 485 out of 1000. n tweets collected so far: 48267
# on page 486 out of 1000. n tweets collected so far: 48367
# on page 487 out of 1000. n tweets collected so far: 48465
# on page 488 out of 1000. n tweets collected so far: 48565
# on page 489 out of 1000. n tweets collected so far: 48664
# on page 490 out of 1000. n tweets collected so far: 48764
# on page 491 out of 1000. n tweets collected so far: 48864
# on page 492 out of 1000. n tweets collected so far: 48963
# on page 493 out of 1000. n tweets collected so far: 49063
# on page 494 out of 1000. n tweets collected so far: 49163
# on page 495 out of 1000. n tweets collected so far: 49263
# on page 496 out of 1000. n tweets collected so far: 49362
# on page 497 out of 1000. n tweets collected so far: 49462
# on page 498 out of 1000. n tweets collected so far: 49562
# on page 499 out of 1000. n tweets collected so far: 49662
# on page 500 out of 1000. n tweets collected so far: 49761
# on page 501 out of 1000. n tweets collected so far: 49860
# on page 502 out of 1000. n tweets collected so far: 49960
# on page 503 out of 1000. n tweets collected so far: 50060
# on page 504 out of 1000. n tweets collected so far: 50159
# on page 505 out of 1000. n tweets collected so far: 50259
# on page 506 out of 1000. n tweets collected so far: 50358
# on page 507 out of 1000. n tweets collected so far: 50458
# on page 508 out of 1000. n tweets collected so far: 50558
# on page 509 out of 1000. n tweets collected so far: 50658
# on page 510 out of 1000. n tweets collected so far: 50758
# on page 511 out of 1000. n tweets collected so far: 50858
# on page 512 out of 1000. n tweets collected so far: 50957
# on page 513 out of 1000. n tweets collected so far: 51057
# on page 514 out of 1000. n tweets collected so far: 51157
# on page 515 out of 1000. n tweets collected so far: 51257
# on page 516 out of 1000. n tweets collected so far: 51357
# on page 517 out of 1000. n tweets collected so far: 51456
# on page 518 out of 1000. n tweets collected so far: 51555
# on page 519 out of 1000. n tweets collected so far: 51654
# on page 520 out of 1000. n tweets collected so far: 51754
# on page 521 out of 1000. n tweets collected so far: 51854
# on page 522 out of 1000. n tweets collected so far: 51954
# on page 523 out of 1000. n tweets collected so far: 52054
# on page 524 out of 1000. n tweets collected so far: 52154
# on page 525 out of 1000. n tweets collected so far: 52253
# on page 526 out of 1000. n tweets collected so far: 52353
# on page 527 out of 1000. n tweets collected so far: 52453
# on page 528 out of 1000. n tweets collected so far: 52552
# on page 529 out of 1000. n tweets collected so far: 52651
# on page 530 out of 1000. n tweets collected so far: 52749
# on page 531 out of 1000. n tweets collected so far: 52849
# on page 532 out of 1000. n tweets collected so far: 52948
# on page 533 out of 1000. n tweets collected so far: 53048
# on page 534 out of 1000. n tweets collected so far: 53148
# on page 535 out of 1000. n tweets collected so far: 53248
# on page 536 out of 1000. n tweets collected so far: 53347
# on page 537 out of 1000. n tweets collected so far: 53447
# on page 538 out of 1000. n tweets collected so far: 53547
# on page 539 out of 1000. n tweets collected so far: 53645
# on page 540 out of 1000. n tweets collected so far: 53744
# on page 541 out of 1000. n tweets collected so far: 53844
# on page 542 out of 1000. n tweets collected so far: 53944
# on page 543 out of 1000. n tweets collected so far: 54044
# on page 544 out of 1000. n tweets collected so far: 54143
# on page 545 out of 1000. n tweets collected so far: 54242
# on page 546 out of 1000. n tweets collected so far: 54342
# on page 547 out of 1000. n tweets collected so far: 54440
# on page 548 out of 1000. n tweets collected so far: 54540
# on page 549 out of 1000. n tweets collected so far: 54639
# on page 550 out of 1000. n tweets collected so far: 54739
# on page 551 out of 1000. n tweets collected so far: 54839
# on page 552 out of 1000. n tweets collected so far: 54939
# on page 553 out of 1000. n tweets collected so far: 55039
# on page 554 out of 1000. n tweets collected so far: 55139
# on page 555 out of 1000. n tweets collected so far: 55239
# on page 556 out of 1000. n tweets collected so far: 55339
# on page 557 out of 1000. n tweets collected so far: 55438
# on page 558 out of 1000. n tweets collected so far: 55538
# on page 559 out of 1000. n tweets collected so far: 55638
# on page 560 out of 1000. n tweets collected so far: 55738
# on page 561 out of 1000. n tweets collected so far: 55838
# on page 562 out of 1000. n tweets collected so far: 55938
# on page 563 out of 1000. n tweets collected so far: 56038
# on page 564 out of 1000. n tweets collected so far: 56137
# on page 565 out of 1000. n tweets collected so far: 56237
# on page 566 out of 1000. n tweets collected so far: 56336
# on page 567 out of 1000. n tweets collected so far: 56436
# on page 568 out of 1000. n tweets collected so far: 56536
# on page 569 out of 1000. n tweets collected so far: 56636
# on page 570 out of 1000. n tweets collected so far: 56736
# on page 571 out of 1000. n tweets collected so far: 56836
# on page 572 out of 1000. n tweets collected so far: 56936
# on page 573 out of 1000. n tweets collected so far: 57036
# on page 574 out of 1000. n tweets collected so far: 57136
# on page 575 out of 1000. n tweets collected so far: 57236
# on page 576 out of 1000. n tweets collected so far: 57336
# on page 577 out of 1000. n tweets collected so far: 57436
# on page 578 out of 1000. n tweets collected so far: 57535
# on page 579 out of 1000. n tweets collected so far: 57635
# on page 580 out of 1000. n tweets collected so far: 57735
# on page 581 out of 1000. n tweets collected so far: 57835
# on page 582 out of 1000. n tweets collected so far: 57935
# on page 583 out of 1000. n tweets collected so far: 58035
# on page 584 out of 1000. n tweets collected so far: 58135
# on page 585 out of 1000. n tweets collected so far: 58234
# on page 586 out of 1000. n tweets collected so far: 58334
# on page 587 out of 1000. n tweets collected so far: 58434
# on page 588 out of 1000. n tweets collected so far: 58534
# on page 589 out of 1000. n tweets collected so far: 58633
# on page 590 out of 1000. n tweets collected so far: 58733
# on page 591 out of 1000. n tweets collected so far: 58832
# on page 592 out of 1000. n tweets collected so far: 58932
# on page 593 out of 1000. n tweets collected so far: 59031
# on page 594 out of 1000. n tweets collected so far: 59131
# on page 595 out of 1000. n tweets collected so far: 59228
# on page 596 out of 1000. n tweets collected so far: 59328
# on page 597 out of 1000. n tweets collected so far: 59428
# on page 598 out of 1000. n tweets collected so far: 59527
# on page 599 out of 1000. n tweets collected so far: 59626
# on page 600 out of 1000. n tweets collected so far: 59726
# on page 601 out of 1000. n tweets collected so far: 59826
# on page 602 out of 1000. n tweets collected so far: 59926
# on page 603 out of 1000. n tweets collected so far: 60026
# on page 604 out of 1000. n tweets collected so far: 60126
# on page 605 out of 1000. n tweets collected so far: 60225
# on page 606 out of 1000. n tweets collected so far: 60325
# on page 607 out of 1000. n tweets collected so far: 60425
# on page 608 out of 1000. n tweets collected so far: 60525
# on page 609 out of 1000. n tweets collected so far: 60625
# on page 610 out of 1000. n tweets collected so far: 60724
# on page 611 out of 1000. n tweets collected so far: 60824
# on page 612 out of 1000. n tweets collected so far: 60923
# on page 613 out of 1000. n tweets collected so far: 61022
# on page 614 out of 1000. n tweets collected so far: 61122
# on page 615 out of 1000. n tweets collected so far: 61222
# on page 616 out of 1000. n tweets collected so far: 61322
# on page 617 out of 1000. n tweets collected so far: 61422
# on page 618 out of 1000. n tweets collected so far: 61522
# on page 619 out of 1000. n tweets collected so far: 61621
# on page 620 out of 1000. n tweets collected so far: 61721
# on page 621 out of 1000. n tweets collected so far: 61820
# on page 622 out of 1000. n tweets collected so far: 61920
# on page 623 out of 1000. n tweets collected so far: 62020
# on page 624 out of 1000. n tweets collected so far: 62120
# on page 625 out of 1000. n tweets collected so far: 62220
# on page 626 out of 1000. n tweets collected so far: 62320
# on page 627 out of 1000. n tweets collected so far: 62420
# on page 628 out of 1000. n tweets collected so far: 62520
# on page 629 out of 1000. n tweets collected so far: 62619
# on page 630 out of 1000. n tweets collected so far: 62719
# on page 631 out of 1000. n tweets collected so far: 62819
# on page 632 out of 1000. n tweets collected so far: 62918
# on page 633 out of 1000. n tweets collected so far: 63018
# on page 634 out of 1000. n tweets collected so far: 63116
# on page 635 out of 1000. n tweets collected so far: 63216
# on page 636 out of 1000. n tweets collected so far: 63316
# on page 637 out of 1000. n tweets collected so far: 63416
# on page 638 out of 1000. n tweets collected so far: 63514
# on page 639 out of 1000. n tweets collected so far: 63614
# on page 640 out of 1000. n tweets collected so far: 63714
# on page 641 out of 1000. n tweets collected so far: 63814
# on page 642 out of 1000. n tweets collected so far: 63914
# on page 643 out of 1000. n tweets collected so far: 64013
# on page 644 out of 1000. n tweets collected so far: 64111
# on page 645 out of 1000. n tweets collected so far: 64210
# on page 646 out of 1000. n tweets collected so far: 64309
# on page 647 out of 1000. n tweets collected so far: 64409
# on page 648 out of 1000. n tweets collected so far: 64509
# on page 649 out of 1000. n tweets collected so far: 64608
# on page 650 out of 1000. n tweets collected so far: 64708
# on page 651 out of 1000. n tweets collected so far: 64807
# on page 652 out of 1000. n tweets collected so far: 64907
# on page 653 out of 1000. n tweets collected so far: 65006
# on page 654 out of 1000. n tweets collected so far: 65106
# on page 655 out of 1000. n tweets collected so far: 65206
# on page 656 out of 1000. n tweets collected so far: 65303
# on page 657 out of 1000. n tweets collected so far: 65402
# on page 658 out of 1000. n tweets collected so far: 65501
# on page 659 out of 1000. n tweets collected so far: 65601
# on page 660 out of 1000. n tweets collected so far: 65699
# on page 661 out of 1000. n tweets collected so far: 65798
# on page 662 out of 1000. n tweets collected so far: 65896
# on page 663 out of 1000. n tweets collected so far: 65996
# on page 664 out of 1000. n tweets collected so far: 66094
# on page 665 out of 1000. n tweets collected so far: 66193
# on page 666 out of 1000. n tweets collected so far: 66292
# on page 667 out of 1000. n tweets collected so far: 66391
# on page 668 out of 1000. n tweets collected so far: 66491
# on page 669 out of 1000. n tweets collected so far: 66591
# on page 670 out of 1000. n tweets collected so far: 66689
# on page 671 out of 1000. n tweets collected so far: 66789
# on page 672 out of 1000. n tweets collected so far: 66889
# on page 673 out of 1000. n tweets collected so far: 66989
# on page 674 out of 1000. n tweets collected so far: 67088
# on page 675 out of 1000. n tweets collected so far: 67188
# on page 676 out of 1000. n tweets collected so far: 67288
# on page 677 out of 1000. n tweets collected so far: 67387
# on page 678 out of 1000. n tweets collected so far: 67487
# on page 679 out of 1000. n tweets collected so far: 67587
# on page 680 out of 1000. n tweets collected so far: 67687
# on page 681 out of 1000. n tweets collected so far: 67787
# on page 682 out of 1000. n tweets collected so far: 67887
# on page 683 out of 1000. n tweets collected so far: 67987
# on page 684 out of 1000. n tweets collected so far: 68087
# on page 685 out of 1000. n tweets collected so far: 68187
# on page 686 out of 1000. n tweets collected so far: 68287
# on page 687 out of 1000. n tweets collected so far: 68386
# on page 688 out of 1000. n tweets collected so far: 68486
# on page 689 out of 1000. n tweets collected so far: 68586
# on page 690 out of 1000. n tweets collected so far: 68684
# on page 691 out of 1000. n tweets collected so far: 68783
# on page 692 out of 1000. n tweets collected so far: 68883
# on page 693 out of 1000. n tweets collected so far: 68983
# on page 694 out of 1000. n tweets collected so far: 69081
# on page 695 out of 1000. n tweets collected so far: 69181
# on page 696 out of 1000. n tweets collected so far: 69281
# on page 697 out of 1000. n tweets collected so far: 69380
# on page 698 out of 1000. n tweets collected so far: 69480
# on page 699 out of 1000. n tweets collected so far: 69579
# on page 700 out of 1000. n tweets collected so far: 69678
# on page 701 out of 1000. n tweets collected so far: 69778
# on page 702 out of 1000. n tweets collected so far: 69878
# on page 703 out of 1000. n tweets collected so far: 69977
# on page 704 out of 1000. n tweets collected so far: 70076
# on page 705 out of 1000. n tweets collected so far: 70176
# on page 706 out of 1000. n tweets collected so far: 70274
# on page 707 out of 1000. n tweets collected so far: 70374
# on page 708 out of 1000. n tweets collected so far: 70474
# on page 709 out of 1000. n tweets collected so far: 70574
# on page 710 out of 1000. n tweets collected so far: 70674
# on page 711 out of 1000. n tweets collected so far: 70772
# on page 712 out of 1000. n tweets collected so far: 70872
# on page 713 out of 1000. n tweets collected so far: 70972
# on page 714 out of 1000. n tweets collected so far: 71071
# on page 715 out of 1000. n tweets collected so far: 71170
# on page 716 out of 1000. n tweets collected so far: 71270
# on page 717 out of 1000. n tweets collected so far: 71370
# on page 718 out of 1000. n tweets collected so far: 71468
# on page 719 out of 1000. n tweets collected so far: 71568
# on page 720 out of 1000. n tweets collected so far: 71666
# on page 721 out of 1000. n tweets collected so far: 71765
# on page 722 out of 1000. n tweets collected so far: 71865
# on page 723 out of 1000. n tweets collected so far: 71965
# on page 724 out of 1000. n tweets collected so far: 72065
# on page 725 out of 1000. n tweets collected so far: 72165
# on page 726 out of 1000. n tweets collected so far: 72265
# on page 727 out of 1000. n tweets collected so far: 72365
# on page 728 out of 1000. n tweets collected so far: 72465
# on page 729 out of 1000. n tweets collected so far: 72565
# on page 730 out of 1000. n tweets collected so far: 72665
# on page 731 out of 1000. n tweets collected so far: 72765
# on page 732 out of 1000. n tweets collected so far: 72865
# on page 733 out of 1000. n tweets collected so far: 72964
# on page 734 out of 1000. n tweets collected so far: 73064
# on page 735 out of 1000. n tweets collected so far: 73162
# on page 736 out of 1000. n tweets collected so far: 73262
# on page 737 out of 1000. n tweets collected so far: 73362
# on page 738 out of 1000. n tweets collected so far: 73462
# on page 739 out of 1000. n tweets collected so far: 73562
# on page 740 out of 1000. n tweets collected so far: 73662
# on page 741 out of 1000. n tweets collected so far: 73762
# on page 742 out of 1000. n tweets collected so far: 73862
# on page 743 out of 1000. n tweets collected so far: 73962
# on page 744 out of 1000. n tweets collected so far: 74061
# on page 745 out of 1000. n tweets collected so far: 74161
# on page 746 out of 1000. n tweets collected so far: 74261
# on page 747 out of 1000. n tweets collected so far: 74361
# on page 748 out of 1000. n tweets collected so far: 74461
# on page 749 out of 1000. n tweets collected so far: 74560
# on page 750 out of 1000. n tweets collected so far: 74660
# on page 751 out of 1000. n tweets collected so far: 74760
# on page 752 out of 1000. n tweets collected so far: 74860
# on page 753 out of 1000. n tweets collected so far: 74958
# on page 754 out of 1000. n tweets collected so far: 75057
# on page 755 out of 1000. n tweets collected so far: 75157
# on page 756 out of 1000. n tweets collected so far: 75257
# on page 757 out of 1000. n tweets collected so far: 75357
# on page 758 out of 1000. n tweets collected so far: 75456
# on page 759 out of 1000. n tweets collected so far: 75556
# on page 760 out of 1000. n tweets collected so far: 75655
# on page 761 out of 1000. n tweets collected so far: 75755
# on page 762 out of 1000. n tweets collected so far: 75854
# on page 763 out of 1000. n tweets collected so far: 75954
# on page 764 out of 1000. n tweets collected so far: 76054
# on page 765 out of 1000. n tweets collected so far: 76153
# on page 766 out of 1000. n tweets collected so far: 76253
# on page 767 out of 1000. n tweets collected so far: 76352
# on page 768 out of 1000. n tweets collected so far: 76450
# on page 769 out of 1000. n tweets collected so far: 76550
# on page 770 out of 1000. n tweets collected so far: 76648
# on page 771 out of 1000. n tweets collected so far: 76748
# on page 772 out of 1000. n tweets collected so far: 76848
# on page 773 out of 1000. n tweets collected so far: 76948
# on page 774 out of 1000. n tweets collected so far: 77047
# on page 775 out of 1000. n tweets collected so far: 77147
# on page 776 out of 1000. n tweets collected so far: 77247
# on page 777 out of 1000. n tweets collected so far: 77347
# on page 778 out of 1000. n tweets collected so far: 77447
# on page 779 out of 1000. n tweets collected so far: 77547
# on page 780 out of 1000. n tweets collected so far: 77647
# on page 781 out of 1000. n tweets collected so far: 77747
# on page 782 out of 1000. n tweets collected so far: 77846
# on page 783 out of 1000. n tweets collected so far: 77946
# on page 784 out of 1000. n tweets collected so far: 78046
# on page 785 out of 1000. n tweets collected so far: 78144
# on page 786 out of 1000. n tweets collected so far: 78243
# on page 787 out of 1000. n tweets collected so far: 78342
# on page 788 out of 1000. n tweets collected so far: 78439
# on page 789 out of 1000. n tweets collected so far: 78539
# on page 790 out of 1000. n tweets collected so far: 78638
# on page 791 out of 1000. n tweets collected so far: 78738
# on page 792 out of 1000. n tweets collected so far: 78837
# on page 793 out of 1000. n tweets collected so far: 78937
# on page 794 out of 1000. n tweets collected so far: 79037
# on page 795 out of 1000. n tweets collected so far: 79135
# on page 796 out of 1000. n tweets collected so far: 79235
# on page 797 out of 1000. n tweets collected so far: 79335
# on page 798 out of 1000. n tweets collected so far: 79435
# on page 799 out of 1000. n tweets collected so far: 79535
# on page 800 out of 1000. n tweets collected so far: 79635
# on page 801 out of 1000. n tweets collected so far: 79735
# on page 802 out of 1000. n tweets collected so far: 79834
# on page 803 out of 1000. n tweets collected so far: 79932
# on page 804 out of 1000. n tweets collected so far: 80031
# on page 805 out of 1000. n tweets collected so far: 80131
# on page 806 out of 1000. n tweets collected so far: 80231
# on page 807 out of 1000. n tweets collected so far: 80331
# on page 808 out of 1000. n tweets collected so far: 80431
# on page 809 out of 1000. n tweets collected so far: 80530
# on page 810 out of 1000. n tweets collected so far: 80630
# on page 811 out of 1000. n tweets collected so far: 80730
# on page 812 out of 1000. n tweets collected so far: 80829
# on page 813 out of 1000. n tweets collected so far: 80929
# on page 814 out of 1000. n tweets collected so far: 81028
# on page 815 out of 1000. n tweets collected so far: 81127
# on page 816 out of 1000. n tweets collected so far: 81227
# on page 817 out of 1000. n tweets collected so far: 81326
# on page 818 out of 1000. n tweets collected so far: 81425
# on page 819 out of 1000. n tweets collected so far: 81524
# on page 820 out of 1000. n tweets collected so far: 81624
# on page 821 out of 1000. n tweets collected so far: 81724
# on page 822 out of 1000. n tweets collected so far: 81824
# on page 823 out of 1000. n tweets collected so far: 81924
# on page 824 out of 1000. n tweets collected so far: 82024
# on page 825 out of 1000. n tweets collected so far: 82123
# on page 826 out of 1000. n tweets collected so far: 82223
# on page 827 out of 1000. n tweets collected so far: 82323
# on page 828 out of 1000. n tweets collected so far: 82421
# on page 829 out of 1000. n tweets collected so far: 82520
# on page 830 out of 1000. n tweets collected so far: 82619
# on page 831 out of 1000. n tweets collected so far: 82719
# on page 832 out of 1000. n tweets collected so far: 82819
# on page 833 out of 1000. n tweets collected so far: 82919
# on page 834 out of 1000. n tweets collected so far: 83019
# on page 835 out of 1000. n tweets collected so far: 83119
# on page 836 out of 1000. n tweets collected so far: 83219
# on page 837 out of 1000. n tweets collected so far: 83317
# on page 838 out of 1000. n tweets collected so far: 83417
# on page 839 out of 1000. n tweets collected so far: 83516
# on page 840 out of 1000. n tweets collected so far: 83616
# on page 841 out of 1000. n tweets collected so far: 83715
# on page 842 out of 1000. n tweets collected so far: 83814
# on page 843 out of 1000. n tweets collected so far: 83914
# on page 844 out of 1000. n tweets collected so far: 84014
# on page 845 out of 1000. n tweets collected so far: 84112
# on page 846 out of 1000. n tweets collected so far: 84211
# on page 847 out of 1000. n tweets collected so far: 84311
# on page 848 out of 1000. n tweets collected so far: 84411
# on page 849 out of 1000. n tweets collected so far: 84511
# on page 850 out of 1000. n tweets collected so far: 84611
# on page 851 out of 1000. n tweets collected so far: 84711
# on page 852 out of 1000. n tweets collected so far: 84811
# on page 853 out of 1000. n tweets collected so far: 84911
# on page 854 out of 1000. n tweets collected so far: 85010
# on page 855 out of 1000. n tweets collected so far: 85109
# on page 856 out of 1000. n tweets collected so far: 85208
# on page 857 out of 1000. n tweets collected so far: 85308
# on page 858 out of 1000. n tweets collected so far: 85408
# on page 859 out of 1000. n tweets collected so far: 85508
# on page 860 out of 1000. n tweets collected so far: 85607
# on page 861 out of 1000. n tweets collected so far: 85707
# on page 862 out of 1000. n tweets collected so far: 85806
# on page 863 out of 1000. n tweets collected so far: 85906
# on page 864 out of 1000. n tweets collected so far: 86006
# on page 865 out of 1000. n tweets collected so far: 86104
# on page 866 out of 1000. n tweets collected so far: 86204
# on page 867 out of 1000. n tweets collected so far: 86304
# on page 868 out of 1000. n tweets collected so far: 86403
# on page 869 out of 1000. n tweets collected so far: 86503
# on page 870 out of 1000. n tweets collected so far: 86603
# on page 871 out of 1000. n tweets collected so far: 86703
# on page 872 out of 1000. n tweets collected so far: 86803
# on page 873 out of 1000. n tweets collected so far: 86903
# on page 874 out of 1000. n tweets collected so far: 87002
# on page 875 out of 1000. n tweets collected so far: 87101
# on page 876 out of 1000. n tweets collected so far: 87201
# on page 877 out of 1000. n tweets collected so far: 87301
# on page 878 out of 1000. n tweets collected so far: 87401
# on page 879 out of 1000. n tweets collected so far: 87500
# on page 880 out of 1000. n tweets collected so far: 87599
# on page 881 out of 1000. n tweets collected so far: 87699
# on page 882 out of 1000. n tweets collected so far: 87799
# on page 883 out of 1000. n tweets collected so far: 87898
# on page 884 out of 1000. n tweets collected so far: 87997
# on page 885 out of 1000. n tweets collected so far: 88096
# on page 886 out of 1000. n tweets collected so far: 88196
# on page 887 out of 1000. n tweets collected so far: 88295
# on page 888 out of 1000. n tweets collected so far: 88394
# on page 889 out of 1000. n tweets collected so far: 88494
# on page 890 out of 1000. n tweets collected so far: 88594
# on page 891 out of 1000. n tweets collected so far: 88694
# on page 892 out of 1000. n tweets collected so far: 88793
# on page 893 out of 1000. n tweets collected so far: 88893
# on page 894 out of 1000. n tweets collected so far: 88993
# on page 895 out of 1000. n tweets collected so far: 89093
# on page 896 out of 1000. n tweets collected so far: 89193
# on page 897 out of 1000. n tweets collected so far: 89293
# on page 898 out of 1000. n tweets collected so far: 89393
# on page 899 out of 1000. n tweets collected so far: 89493
# Rate limit exceeded. Sleeping for 285 seconds.
# on page 900 out of 1000. n tweets collected so far: 89592
# on page 901 out of 1000. n tweets collected so far: 89691
# on page 902 out of 1000. n tweets collected so far: 89790
# on page 903 out of 1000. n tweets collected so far: 89889
# on page 904 out of 1000. n tweets collected so far: 89989
# on page 905 out of 1000. n tweets collected so far: 90089
# on page 906 out of 1000. n tweets collected so far: 90189
# on page 907 out of 1000. n tweets collected so far: 90289
# on page 908 out of 1000. n tweets collected so far: 90389
# on page 909 out of 1000. n tweets collected so far: 90489
# on page 910 out of 1000. n tweets collected so far: 90589
# on page 911 out of 1000. n tweets collected so far: 90689
# on page 912 out of 1000. n tweets collected so far: 90789
# on page 913 out of 1000. n tweets collected so far: 90888
# on page 914 out of 1000. n tweets collected so far: 90988
# on page 915 out of 1000. n tweets collected so far: 91088
# on page 916 out of 1000. n tweets collected so far: 91188
# on page 917 out of 1000. n tweets collected so far: 91288
# on page 918 out of 1000. n tweets collected so far: 91388
# on page 919 out of 1000. n tweets collected so far: 91488
# on page 920 out of 1000. n tweets collected so far: 91588
# on page 921 out of 1000. n tweets collected so far: 91688
# on page 922 out of 1000. n tweets collected so far: 91788
# on page 923 out of 1000. n tweets collected so far: 91888
# on page 924 out of 1000. n tweets collected so far: 91987
# on page 925 out of 1000. n tweets collected so far: 92087
# on page 926 out of 1000. n tweets collected so far: 92186
# on page 927 out of 1000. n tweets collected so far: 92286
# on page 928 out of 1000. n tweets collected so far: 92386
# on page 929 out of 1000. n tweets collected so far: 92486
# on page 930 out of 1000. n tweets collected so far: 92585
# on page 931 out of 1000. n tweets collected so far: 92685
# on page 932 out of 1000. n tweets collected so far: 92784
# on page 933 out of 1000. n tweets collected so far: 92884
# on page 934 out of 1000. n tweets collected so far: 92983
# on page 935 out of 1000. n tweets collected so far: 93083
# on page 936 out of 1000. n tweets collected so far: 93183
# on page 937 out of 1000. n tweets collected so far: 93283
# on page 938 out of 1000. n tweets collected so far: 93383
# on page 939 out of 1000. n tweets collected so far: 93483
# on page 940 out of 1000. n tweets collected so far: 93582
# on page 941 out of 1000. n tweets collected so far: 93682
# on page 942 out of 1000. n tweets collected so far: 93782
# on page 943 out of 1000. n tweets collected so far: 93882
# on page 944 out of 1000. n tweets collected so far: 93982
# on page 945 out of 1000. n tweets collected so far: 94081
# on page 946 out of 1000. n tweets collected so far: 94181
# on page 947 out of 1000. n tweets collected so far: 94281
# on page 948 out of 1000. n tweets collected so far: 94381
# on page 949 out of 1000. n tweets collected so far: 94481
# on page 950 out of 1000. n tweets collected so far: 94580
# on page 951 out of 1000. n tweets collected so far: 94679
# on page 952 out of 1000. n tweets collected so far: 94779
# on page 953 out of 1000. n tweets collected so far: 94878
# on page 954 out of 1000. n tweets collected so far: 94976
# on page 955 out of 1000. n tweets collected so far: 95075
# on page 956 out of 1000. n tweets collected so far: 95173
# on page 957 out of 1000. n tweets collected so far: 95273
# on page 958 out of 1000. n tweets collected so far: 95373
# on page 959 out of 1000. n tweets collected so far: 95472
# on page 960 out of 1000. n tweets collected so far: 95572
# on page 961 out of 1000. n tweets collected so far: 95672
# on page 962 out of 1000. n tweets collected so far: 95772
# on page 963 out of 1000. n tweets collected so far: 95871
# on page 964 out of 1000. n tweets collected so far: 95971
# on page 965 out of 1000. n tweets collected so far: 96071
# on page 966 out of 1000. n tweets collected so far: 96171
# on page 967 out of 1000. n tweets collected so far: 96271
# on page 968 out of 1000. n tweets collected so far: 96369
# on page 969 out of 1000. n tweets collected so far: 96469
# on page 970 out of 1000. n tweets collected so far: 96569

# %%
tmp_start_time = date_parser.parse("2022-12-04T16:58:16.000Z")

# %%
tmp_start_time
# Out:
# datetime.datetime(2022, 12, 4, 16, 58, 16, tzinfo=tzlocal())

# %%
if bob:
    print('yes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [283], line 1
# ----> 1 if bob:
#       2     print('yes')
#
# NameError: name 'bob' is not defined

# %%
tweets2 = client.search_recent_tweets(
    query=search_terms,
    start_time=time_chunks[0]['start_time'],
    end_time=tmp_start_time,
    expansions=expansions, 
    tweet_fields=tweet_fields,
    media_fields=media_fields,
    user_fields=user_fields,
    max_results=100
)

# %%
tmp0 = []
path = '../data/test/tweets_2022_12_04-16_00_01.json'

with open(path, 'r') as infile:
    for line in infile:
        tmp0.append(json.loads(line))

# %%
mismatched = []

for row in tmp0:
    if row['author_id']!=row['user']['id']:
        mismatched.append(row)

# %%
unique_ids = []
for row in tmp0:
    if row['id'] not in unique_ids:
        unique_ids.append(row['id'])
    else:
        print(f'{row["id"]} is duplicated')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [291], line 4
#       2 for row in tmp0:
#       3     if row['id'] not in unique_ids:
# ----> 4         unique_ids.append(row['id'])
#       5     else:
#       6         print(f'{row["id"]} is duplicated')
#
# KeyboardInterrupt:

# %%
earliest = date_parser.parse('2022-12-04 17:00:01')
delta = datetime.timedelta(minutes=59)
time_chunks = []

for i in range(7):
    tmp = {
        'start_time' : earliest,
        'end_time' : earliest+delta,
        'filename' : 'tweets_'+earliest.strftime('%Y_%m_%d-%H_%M_%S')+'.json'
    }

    time_chunks.append(tmp)
    earliest = earliest + datetime.timedelta(hours=1)

# %%
for chunk in time_chunks:
    print(chunk)
# Out:
# {'start_time': datetime.datetime(2022, 12, 4, 17, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 17, 59, 1), 'filename': 'tweets_2022_12_04-17_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 18, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 18, 59, 1), 'filename': 'tweets_2022_12_04-18_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 19, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 19, 59, 1), 'filename': 'tweets_2022_12_04-19_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 20, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 20, 59, 1), 'filename': 'tweets_2022_12_04-20_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 21, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 21, 59, 1), 'filename': 'tweets_2022_12_04-21_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 22, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 22, 59, 1), 'filename': 'tweets_2022_12_04-22_00_01.json'}
# {'start_time': datetime.datetime(2022, 12, 4, 23, 0, 1), 'end_time': datetime.datetime(2022, 12, 4, 23, 59, 1), 'filename': 'tweets_2022_12_04-23_00_01.json'}
